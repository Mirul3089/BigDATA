# %% [markdown]
# # Lab-5

# %% [markdown]
# # Seaborn Exercises

# %% [markdown]
# * Name:Mirul Patel
# * Student ID:N01489347

# %% [markdown]
# ## Import Numpy, Panda and Matplotlib library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Import Dataset

# %%
df=pd.read_csv('Desktop/iris.csv')
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
# print top 5 row of the dataset

# %% [markdown]
# ## Exercises 1

# %%
sns.distplot(df['sepal.width'])
# Out:
# C:\Users\mirul\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sepal.width', ylabel='Density'>

# %% [markdown]
# ## Exercises 2

# %%
sns.pairplot(df)

# %% [markdown]
# ## Exercises 3

# %%
sns.boxplot(data=df,palette='rainbow',orient='h')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Exercises 4

# %%
# Write the code to show the graph below.

# %% [markdown]
# ## Exercises 5

# %%
g = sns.PairGrid(df)
g.map(plt.scatter)

# %% [markdown]
# ## Exercises 6

# %% [markdown]
# Create a Categorical Plot for the column Sex of the Titanic dataset.

# %%
hf=pd.read_csv('Desktop/Titanic.csv')
sns.catplot(x='Sex',data=hf)

# %% [markdown]
# Please save as Pdf and submit in Blackboard Lab5.
