# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('darkgrid')
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('desktop/stock_market.csv')

# %%
df.head()
# Out:
#   Index        Date         Open         High          Low        Close  \
# 0   HSI  1986-12-31  2568.300049  2568.300049  2568.300049  2568.300049
# 1   HSI  1987-01-02  2540.100098  2540.100098  2540.100098  2540.100098
# 2   HSI  1987-01-05  2552.399902  2552.399902  2552.399902  2552.399902
# 3   HSI  1987-01-06  2583.899902  2583.899902  2583.899902  2583.899902
# 4   HSI  1987-01-07  2607.100098  2607.100098  2607.100098  2607.100098
#
#      Adj Close  Volume    CloseUSD
# 0  2568.300049     0.0  333.879006
# 1  2540.100098     0.0  330.213013
# 2  2552.399902     0.0  331.811987
# 3  2583.899902     0.0  335.906987
# 4  2607.100098     0.0  338.923013

# %%
df.shape
# Out:
# (104224, 9)

# %%
df['Date']=pd.to_datetime(df['Date'])
df.set_index(['Date'],inplace = True)

# %%
df= df.drop('Index',axis=1)
df.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1986-12-31  2568.300049  2568.300049  2568.300049  2568.300049  2568.300049
# 1987-01-02  2540.100098  2540.100098  2540.100098  2540.100098  2540.100098
# 1987-01-05  2552.399902  2552.399902  2552.399902  2552.399902  2552.399902
# 1987-01-06  2583.899902  2583.899902  2583.899902  2583.899902  2583.899902
# 1987-01-07  2607.100098  2607.100098  2607.100098  2607.100098  2607.100098
#
#             Volume    CloseUSD
# Date
# 1986-12-31     0.0  333.879006
# 1987-01-02     0.0  330.213013
# 1987-01-05     0.0  331.811987
# 1987-01-06     0.0  335.906987
# 1987-01-07     0.0  338.923013

# %% [markdown]
# ### check for distribution and skewness using plots

# %%
for col in df.columns:
    sns.distplot(df[col])
    plt.show()

# %%
df.describe()

# %% [markdown]
# ### inference from describe()

# %%
import numpy as np
np.mean(df['High']/df['Low'])
# Out:
# 1.0113344515222602

# %%
#stocks = ['stock'+str(x) for x in range(1,5) ]
#for stock in stocks:
 #   print(stock,end = ' - ')
  #  print(np.mean(df[stock+'_sales']/df[stock]))

# %%
wdf=df.resample('W').mean() # w for week

# %%
wdf.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1965-01-10  1270.602509  1270.602509  1270.602509  1270.602509  1270.602509
# 1965-01-17  1286.570028  1286.570028  1286.570028  1286.570028  1286.570028
# 1965-01-24  1268.637988  1268.637988  1268.637988  1268.637988  1268.637988
# 1965-01-31  1249.089990  1249.089990  1249.089990  1249.089990  1249.089990
# 1965-02-07  1250.959985  1250.959985  1250.959985  1250.959985  1250.959985
#
#             Volume   CloseUSD
# Date
# 1965-01-10     0.0  12.706025
# 1965-01-17     0.0  12.865700
# 1965-01-24     0.0  12.686380
# 1965-01-31     0.0  12.490900
# 1965-02-07     0.0  12.509600

# %%
wdf.shape
# Out:
# (2944, 7)

# %%
plt.figure(figsize=(6,3), dpi=100)
plt.tick_params(axis='x',rotation = 45)
plt.title('weekly sales')
plt.bar(x=wdf.index, height= wdf.Close)
# Out:
# <BarContainer object of 2944 artists>

# %%
plt.figure(figsize=(6,3), dpi=100)
plt.tick_params(axis='x',rotation = 45)
plt.title('weekly sales')
plt.bar(x=wdf.index, height= wdf.CloseUSD)
# Out:
# <BarContainer object of 2944 artists>

# %%
mdf=df.resample('M').mean() # M for month

# %%
mdf.head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1965-01-31  1266.515295  1266.515295  1266.515295  1266.515295  1266.515295
# 1965-02-28  1241.136828  1241.136828  1241.136828  1241.136828  1241.136828
# 1965-03-31  1178.766823  1178.766823  1178.766823  1178.766823  1178.766823
# 1965-04-30  1149.059518  1149.059518  1149.059518  1149.059518  1149.059518
# 1965-05-31  1138.677775  1138.677775  1138.677775  1138.677775  1138.677775
#
#             Volume   CloseUSD
# Date
# 1965-01-31     0.0  12.665153
# 1965-02-28     0.0  12.411368
# 1965-03-31     0.0  11.787668
# 1965-04-30     0.0  11.490595
# 1965-05-31     0.0  11.386778
