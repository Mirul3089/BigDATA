# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import style
# %matplotlib inline

# %%
rd=np.random.randint(10,size=10)

# %%
rd
# Out:
# array([6, 9, 6, 6, 4, 3, 8, 2, 3, 6])

# %%
style.use('ggplot')
plt.plot(rd,'g',label="line one",linewidth=2) #g denotes green color
plt.xlabel('range')
plt.ylabel('numnbers')
plt.title('firstplot')
#plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import style
# %matplotlib inline

# %%
cause= 'test1','test2','test3','test4','test5'
percentile = [62,5,4,5,17]

# %%
plt.figure(figsize=(10,10),dpi=100)#dpi for resolution
explode = (0.05,0,0,0,0)
plt.pie(percentile,labels=cause,explode=explode,autopct='%1.1f%%',startangle=70)
plt.axis('equal')
plt.title('ohio-2012')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('desktop/data/Housing.csv')

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
plt.plot(df['area'])

# %%
plt.boxplot(df['price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x208aaa44310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x208aaa44970>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x208aaa44040>],
#  'medians': [<matplotlib.lines.Line2D at 0x208aaa44e50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x208aaa51160>],
#  'means': []}

# %%
plt.hist(df['price'])
# Out:
# (array([ 61., 163., 139.,  89.,  46.,  25.,  13.,   4.,   1.,   4.]),
#  array([ 1750000.,  2905000.,  4060000.,  5215000.,  6370000.,  7525000.,
#          8680000.,  9835000., 10990000., 12145000., 13300000.]),
#  <BarContainer object of 10 artists>)

# %%
plt.xlabel('price')
plt.ylabel('area')
plt.scatter(x=df['price'],y=df['area'])

# %%
d = {'a':1,'b':2,'c':3}

# %%
plt.bar(x=d.keys(),height=d.values())
# Out:
# <BarContainer object of 3 artists>

# %%
plt.pie(x=d.values(),labels=d.keys())
#plt.savefig('tetst.png')
# Out:
# ([<matplotlib.patches.Wedge at 0x208aad2f4c0>,
# ...
#  [Text(0.9526279355804298, 0.5500000148652441, 'a'),
#   Text(-0.5500000594609755, 0.9526279098330699, 'b'),
#   Text(1.0298943251329445e-07, -1.0999999999999954, 'c')])

# %%
#plotting 3d grapdh
ax=plt.axes(projection='3d')
ax.scatter(df['stories'],df['price'],df['area'])
ax.set_xlabel('Index')
ax.set_ylabel('price')
ax.set_zlabel('area')
# Out:
# Text(0.5, 0, 'area')

# %%
from sklearn.datasets import load_boston
import seaborn as sns

# %%
df=load_boston()
# Out:
# C:\Users\Mirul\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
print(df)
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]]), 'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
# ...

# %%
x_axis=df.data

# %%
y_axis=df.target

# %%
style.use('ggplot')
plt.figure(figsize=(7,7))
plt.hist(y_axis,bins=30)
plt.xlabel('prices in 1000s USD')
plt.ylabel('NUMBER of houses')
plt.show()

# %%
style.use('ggplot')
plt.figure(figsize=(5,5))
plt.scatter(df.data[:,5],df.target)
plt.xlabel('prices in 1000s USD')
plt.ylabel('NUMBER of houses')
plt.show()

# %%
df['feature_names']
import pandas as pd #concatenation
#dfset=pd.DataFrame(data=np.c_[df['data'],df['target']],columns=df['feature_names']+['target']) #concatenation

# %%
#for heatmap
fdata=sns.load_dataset('flights')

# %%
fdata.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
fdata1=fdata.pivot('month','year','passengers')

# %%
fdata1
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(fdata1)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
style.use('ggplot')
plt.figure(figsize=(5,5))
plt.scatter(fdata['month'],fdata['passengers'])
plt.xlabel('prices in 1000s USD')
plt.ylabel('NUMBER of houses')
plt.show()

# %%
job_data=['40','60','30']
lables = 'IT', 'Finance','marketing'
explde = (0.25,0.15,0.25)
plt.pie(job_data,labels=lables,explode=explde)
plt.show()

# %%
#subplots
sns.set_style('whitegrid')

# %%
temp_data=np.random.rand(1,10,1)
wind_data=np.random.rand(1,10,1)
time_hrs=np.random.rand(1,10,1)
humidity_data=np.random.rand(1,10,1)
precipptation_data=np.random.rand(1,10,1)

# %%
plt.figure(figsize=(5,5))
plt.subplots_adjust(hspace=.25)
plt.subplot(1,2,1)
plt.plot(time_hrs,humidity_data,'r')
plt.subplot(1,2,2)
plt.plot(time_hrs,wind_data,'g')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [70], in <cell line: 4>()
#       2 plt.subplots_adjust(hspace=.25)
#       3 plt.subplot(1,2,1)
# ----> 4 plt.plot(time_hrs,humidity_data,'r')
#       5 plt.subplot(1,2,2)
#       6 plt.plot(time_hrs,wind_data,'g')
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
# ...
