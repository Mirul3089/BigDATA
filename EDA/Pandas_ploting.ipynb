# %%
import pandas as pd
df=pd.read_csv('Desktop/data/Housing.csv')

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
df['price'].plot()#df.plot()
# Out:
# <AxesSubplot:>

# %%
df['price'].plot(legend=True)
# Out:
# <AxesSubplot:>

# %%
df.plot(x='bedrooms',y='price',kind='scatter')#kind='scatter'
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
df.plot(title='test',figsize=(15,10),kind='bar')#kind='box',kind='histogram'
# Out:
# <AxesSubplot:title={'center':'test'}>
