# %% [markdown]
# Name:Mirul Patel
# Student Id: N01489347
# Assignment 1

# %% [markdown]
# Question 1

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Question 2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Question 3

# %%
df=pd.read_csv('Desktop\WineQT.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1142 non-null   float64
#  1   volatile acidity      1139 non-null   float64
#  2   citric acid           1140 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1141 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1141 non-null   float64
#  12  Id                    1143 non-null   int64
# dtypes: float64(12), int64(1)
# memory usage: 116.2 KB

# %% [markdown]
# Question 4

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4      5.0   0
# 1      9.8      5.0   1
# ...

# %% [markdown]
# Question 5

# %%
topfivealcohol=df["alcohol"].drop_duplicates().nlargest(5)
topfivealcohol
# Out:
# 462     14.900000
# 96      14.000000
# 787     13.600000
# 1052    13.566667
# 321     13.400000
# Name: alcohol, dtype: float64

# %% [markdown]
# Question 6

# %%
datatype=df["density"].dtypes
datatype
# Out:
# dtype('float64')

# %% [markdown]
# Question 7

# %%
df.isnull().sum()
# Out:
# fixed acidity           1
# volatile acidity        4
# citric acid             3
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 2
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 2
# Id                      0
# dtype: int64

# %% [markdown]
# Question 8

# %%
df.fillna(df["fixed acidity"].mean(skipna=True))
df.fillna(df["volatile acidity"].mean(skipna=True))
df.fillna(df["citric acid"].mean(skipna=True))
df.fillna(df["density"].mean(skipna=True))
df.fillna(df["quality"].mean(skipna=True))
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 368            10.4          0.610000         0.49             2.1      0.200
# 324            11.6          0.580000         0.66             2.2      0.074
# 1046            7.3          0.980000         0.05             2.1      0.061
# 1074            6.7          0.760000         0.02             1.8      0.078
# 1055            7.1          0.875000         0.05             5.7      0.082
# ...             ...               ...          ...             ...        ...
# 793             7.9          0.540000         0.34             2.5      0.076
# 321            11.3          0.620000         0.67             5.2      0.086
# 419             5.0          0.420000         0.24             2.0      0.060
# 1112            7.8          0.600000         0.26             2.0      0.080
# 1075            6.8          5.657318         0.05             2.0      0.070
#
# ...

# %% [markdown]
# Question 9

# %%
df1=df[['alcohol']]
df1.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Question 10

# %%
df.rename(columns={"residual sugar":"sugar"})
# Out:
#       fixed acidity  volatile acidity  citric acid  sugar  chlorides  \
# 0               7.4             0.700         0.00    1.9      0.076
# 1               7.8             0.880         0.00    2.6      0.098
# 2               7.8             0.760         0.04    2.3      0.092
# 3              11.2             0.280         0.56    1.9      0.075
# 4               7.4             0.700         0.00    1.9      0.076
# ...             ...               ...          ...    ...        ...
# 1138            6.3             0.510         0.13    2.3      0.076
# 1139            6.8             0.620         0.08    1.9      0.068
# 1140            6.2             0.600         0.08    2.0      0.090
# 1141            5.9             0.550         0.10    2.2      0.062
# 1142            5.9             0.645          NaN    2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# Question 11

# %%
df.sort_values(by=['quality','alcohol'], inplace=True)
print(df)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 368            10.4             0.610         0.49             2.1      0.200
# 324            11.6             0.580         0.66             2.2      0.074
# 1046            7.3             0.980         0.05             2.1      0.061
# 1074            6.7             0.760         0.02             1.8      0.078
# 1055            7.1             0.875         0.05             5.7      0.082
# ...             ...               ...          ...             ...        ...
# 793             7.9             0.540         0.34             2.5      0.076
# 321            11.3             0.620         0.67             5.2      0.086
# 419             5.0             0.420         0.24             2.0      0.060
# 1112            7.8             0.600         0.26             2.0      0.080
# 1075            6.8               NaN         0.05             2.0      0.070
#
# ...

# %% [markdown]
# Question 12

# %%
mpg = df['density']
mpg.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Question 13

# %%
g = sns.PairGrid(df)
g.map(plt.scatter)
